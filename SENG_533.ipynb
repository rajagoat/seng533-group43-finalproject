# %%
import os
import time
import psutil
import pandas as pd
import matplotlib.pyplot as plt
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, when, lit
from pyspark.ml.feature import StringIndexer, OneHotEncoder, VectorAssembler
from pyspark.ml.regression import LinearRegression
from pyspark.ml import Pipeline
from pyspark.ml.evaluation import RegressionEvaluator
from itertools import product
from google.colab import drive
import matplotlib.pyplot as plt
drive.mount('/content/drive')
excel_filename = "/content/drive/MyDrive/SENG_533/storm_experiment_results.xlsx"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Parameter values for iteration
num_cores_values = [1, 2, 4, 8]           # CPU cores
driver_memory_values = ["8g"]             # Fixed at 8GB for Phase 2
parallelism_values = [2, 4, 8, 16]        # Parallelism levels
batch_interval = 0.5                      # Batch interval in seconds
dataset_path = "/content/drive/MyDrive/SENG_533/Datasets/flights_sample_3m.csv"

pandas_data_file_lower = dataset_path.lower()
if "1k" in pandas_data_file_lower:
    file_size = "1k"
elif "500k" in pandas_data_file_lower:
    file_size = "500k"
elif "3m" in pandas_data_file_lower:
    file_size = "3m"
else:
    file_size = "unknown"

# Define Excel filename and columns for results (including new file_size column)
excel_filename = "/content/drive/MyDrive/SENG_533/spark_phase2_results.xlsx"  # Using new file for Phase 2
columns = [
    "num_cores",
    "driver_memory",
    "parallelism",
    "batch_interval",
    "file_size",  # file size category
    "train_duration_s",
    "train_count",
    "train_throughput_records_s",
    "pred_duration_s",
    "test_count",
    "pred_throughput_records_s",
    "rmse",
    "r2",
    "cpu_usage_start_percent",
    "cpu_usage_end_percent",
    "mem_used_at_start_mb",
    "mem_used_at_end_mb",
    "timestamp"
]

# Check if the Excel file exists; load existing data or create new DataFrame
if os.path.exists(excel_filename):
    results_df = pd.read_excel(excel_filename)
    print(f"Loaded existing results from {excel_filename}.")
else:
    results_df = pd.DataFrame(columns=columns)
    print(f"{excel_filename} does not exist. Creating a new results DataFrame.")
# Out:
# Loaded existing results from /content/drive/MyDrive/SENG_533/spark_phase2_results.xlsx.

# %%
for num_cores, driver_memory, parallelism in product(num_cores_values, driver_memory_values, parallelism_values):
    print(f"\nRunning experiment with num_cores={num_cores}, driver_memory={driver_memory}, parallelism={parallelism}")

    # Create a new Spark session for this configuration
    spark = SparkSession.builder \
        .appName("FlightDelayPrediction") \
        .master(f"local[{num_cores}]") \
        .config("spark.driver.memory", driver_memory) \
        .config("spark.default.parallelism", parallelism) \
        .config("spark.sql.shuffle.partitions", parallelism) \
        .getOrCreate()

    print(f"Spark Version: {spark.version}, Parallelism: {spark.sparkContext.defaultParallelism}")
    print(f"Driver memory: {spark.sparkContext._conf.get('spark.driver.memory')}")

    # Load the flight data into a Spark DataFrame
    data = spark.read.csv(dataset_path, header=True, inferSchema=True)

    # Filter out canceled or diverted flights and drop rows with null arrival delay
    data = data.filter((col("CANCELLED") == 0) & (col("DIVERTED") == 0))
    data = data.dropna(subset=["ARR_DELAY"])

    # Fill missing weather delay values with 0 and derive a categorical weather condition feature
    data = data.fillna({"DELAY_DUE_WEATHER": 0})
    data = data.withColumn("WeatherCond", when(col("DELAY_DUE_WEATHER") > 0, lit("Bad")).otherwise(lit("Normal")))
    data.select("DISTANCE", "CRS_DEP_TIME", "WeatherCond", "ARR_DELAY").show(5)

    # Define the feature transformers and the regression model
    weather_indexer = StringIndexer(inputCol="WeatherCond", outputCol="WeatherIndex", handleInvalid="keep")
    weather_encoder = OneHotEncoder(inputCol="WeatherIndex", outputCol="WeatherVec")
    assembler = VectorAssembler(inputCols=["DISTANCE", "CRS_DEP_TIME", "WeatherVec"], outputCol="features")
    lr = LinearRegression(labelCol="ARR_DELAY", featuresCol="features")

    # Build the pipeline
    pipeline = Pipeline(stages=[weather_indexer, weather_encoder, assembler, lr])

    # Split data into training and test sets
    train_df, test_df = data.randomSplit([0.8, 0.2], seed=42)
    train_count = train_df.count()
    test_count = test_df.count()
    print(f"Training set size: {train_count} records, Test set size: {test_count} records")

    # Record system stats BEFORE training starts
    cpu_usage_start = psutil.cpu_percent(interval=None)
    mem_info_start = psutil.virtual_memory()
    mem_used_start_mb = mem_info_start.used / (1024 * 1024)

    # Training: record training time and count
    start_time = time.time()
    model_pipeline = pipeline.fit(train_df)
    train_duration = time.time() - start_time

    # Record system stats AFTER training
    cpu_usage_end = psutil.cpu_percent(interval=None)
    mem_info_end = psutil.virtual_memory()
    mem_used_end_mb = mem_info_end.used / (1024 * 1024)

    train_throughput = train_count / train_duration if train_duration > 0 else float("inf")

    # Prediction: record prediction time and count
    pred_start = time.time()
    predictions = model_pipeline.transform(test_df).cache()
    predictions.count()  # Force evaluation
    pred_duration = time.time() - pred_start
    pred_throughput = test_count / pred_duration if pred_duration > 0 else float("inf")

    # Evaluate model predictions using RMSE and R^2
    evaluator = RegressionEvaluator(labelCol="ARR_DELAY", predictionCol="prediction")
    rmse = evaluator.setMetricName("rmse").evaluate(predictions)
    r2 = evaluator.setMetricName("r2").evaluate(predictions)

    print("\n--- Performance Metrics ---")
    print(f"Training latency: {train_duration:.2f} s for {train_count} records")
    print(f"Training throughput: {train_throughput:.1f} records/s")
    print(f"Prediction latency: {pred_duration:.2f} s for {test_count} records")
    print(f"Prediction throughput: {pred_throughput:.1f} records/s")
    print(f"RMSE: {rmse:.2f}, R^2: {r2:.3f}")
    print(f"Default parallelism (tasks): {spark.sparkContext.defaultParallelism}")
    print(f"Train Data partitions: {train_df.rdd.getNumPartitions()}, Test Data partitions: {test_df.rdd.getNumPartitions()}")

    # Log experiment data for this configuration
    experiment_data = {
        "num_cores": num_cores,
        "driver_memory": driver_memory,
        "parallelism": parallelism,
        "batch_interval": batch_interval,
        "file_size": file_size,
        "train_duration_s": train_duration,
        "train_count": train_count,
        "train_throughput_records_s": train_throughput,
        "pred_duration_s": pred_duration,
        "test_count": test_count,
        "pred_throughput_records_s": pred_throughput,
        "rmse": rmse,
        "r2": r2,
        "cpu_usage_start_percent": cpu_usage_start,
        "cpu_usage_end_percent": cpu_usage_end,
        "mem_used_at_start_mb": mem_used_start_mb,
        "mem_used_at_end_mb": mem_used_end_mb,
        "timestamp": time.strftime("%Y-%m-%d %H:%M:%S"),
    }

    results_df = pd.concat([results_df, pd.DataFrame([experiment_data])], ignore_index=True)
    print("\nExperiment Data Recorded:")
    print(results_df.tail(1))

    # Stop the Spark session for this configuration
    spark.stop()
# Out:
# Running experiment with num_cores=1, driver_memory=8g, parallelism=2
# Spark Version: 3.5.5, Parallelism: 2
# Driver memory: 8g
# +--------+------------+-----------+---------+
# |DISTANCE|CRS_DEP_TIME|WeatherCond|ARR_DELAY|
# +--------+------------+-----------+---------+
# |  1065.0|        1155|     Normal|    -14.0|
# |  1399.0|        2120|     Normal|     -5.0|
# |   680.0|         954|     Normal|      0.0|
# |  1589.0|        1609|     Normal|     24.0|
# |   985.0|        1840|     Normal|     -1.0|
# +--------+------------+-----------+---------+
# only showing top 5 rows
#
# Training set size: 2330975 records, Test set size: 582827 records
#
# --- Performance Metrics ---
# Training latency: 125.54 s for 2330975 records
# Training throughput: 18567.7 records/s
# Prediction latency: 47.75 s for 582827 records
# Prediction throughput: 12205.5 records/s
# RMSE: 50.20, R^2: 0.047
# Default parallelism (tasks): 2
# Train Data partitions: 5, Test Data partitions: 5
#
# Experiment Data Recorded:
#     num_cores driver_memory  parallelism  batch_interval file_size  \
# 32          1            8g            2             0.5        3m
#
#     train_duration_s  train_count  train_throughput_records_s  \
# 32        125.539401      2330975                18567.676641
#
#     pred_duration_s  test_count  pred_throughput_records_s       rmse  \
# 32         47.75128      582827               12205.473785  50.200062
#
#          r2  cpu_usage_start_percent  cpu_usage_end_percent  \
# 32  0.04725                     27.1                   71.1
#
#     mem_used_at_start_mb  mem_used_at_end_mb            timestamp
# 32           4493.023438         4491.824219  2025-04-09 04:47:29
#
# Running experiment with num_cores=1, driver_memory=8g, parallelism=4
# Spark Version: 3.5.5, Parallelism: 4
# Driver memory: 8g
# +--------+------------+-----------+---------+
# |DISTANCE|CRS_DEP_TIME|WeatherCond|ARR_DELAY|
# +--------+------------+-----------+---------+
# |  1065.0|        1155|     Normal|    -14.0|
# |  1399.0|        2120|     Normal|     -5.0|
# |   680.0|         954|     Normal|      0.0|
# |  1589.0|        1609|     Normal|     24.0|
# |   985.0|        1840|     Normal|     -1.0|
# +--------+------------+-----------+---------+
# only showing top 5 rows
#
# Training set size: 2330975 records, Test set size: 582827 records
#
# --- Performance Metrics ---
# Training latency: 126.89 s for 2330975 records
# Training throughput: 18370.2 records/s
# Prediction latency: 48.11 s for 582827 records
# Prediction throughput: 12115.6 records/s
# RMSE: 50.20, R^2: 0.047
# Default parallelism (tasks): 4
# Train Data partitions: 5, Test Data partitions: 5
#
# Experiment Data Recorded:
#     num_cores driver_memory  parallelism  batch_interval file_size  \
# 33          1            8g            4             0.5        3m
#
#     train_duration_s  train_count  train_throughput_records_s  \
# 33        126.888848      2330975                18370.211655
#
#     pred_duration_s  test_count  pred_throughput_records_s       rmse  \
# 33        48.105343      582827               12115.639663  50.200062
#
#          r2  cpu_usage_start_percent  cpu_usage_end_percent  \
# 33  0.04725                     72.0                   72.0
#
#     mem_used_at_start_mb  mem_used_at_end_mb            timestamp
# 33           4473.035156         4548.824219  2025-04-09 04:52:01
#
# Running experiment with num_cores=1, driver_memory=8g, parallelism=8
# Spark Version: 3.5.5, Parallelism: 8
# Driver memory: 8g
# +--------+------------+-----------+---------+
# |DISTANCE|CRS_DEP_TIME|WeatherCond|ARR_DELAY|
# +--------+------------+-----------+---------+
# |  1065.0|        1155|     Normal|    -14.0|
# |  1399.0|        2120|     Normal|     -5.0|
# |   680.0|         954|     Normal|      0.0|
# |  1589.0|        1609|     Normal|     24.0|
# |   985.0|        1840|     Normal|     -1.0|
# +--------+------------+-----------+---------+
# only showing top 5 rows
#
# Training set size: 2332174 records, Test set size: 581628 records
#
# --- Performance Metrics ---
# Training latency: 122.72 s for 2332174 records
# Training throughput: 19004.5 records/s
# Prediction latency: 46.21 s for 581628 records
# Prediction throughput: 12586.2 records/s
# RMSE: 49.69, R^2: 0.046
# Default parallelism (tasks): 8
# Train Data partitions: 8, Test Data partitions: 8
#
# Experiment Data Recorded:
#     num_cores driver_memory  parallelism  batch_interval file_size  \
# 34          1            8g            8             0.5        3m
#
#     train_duration_s  train_count  train_throughput_records_s  \
# 34        122.717166      2332174                19004.464269
#
#     pred_duration_s  test_count  pred_throughput_records_s       rmse  \
# 34        46.211623      581628               12586.184099  49.685824
#
#           r2  cpu_usage_start_percent  cpu_usage_end_percent  \
# 34  0.045799                     71.9                   72.3
#
#     mem_used_at_start_mb  mem_used_at_end_mb            timestamp
# 34            4556.03125          4558.65625  2025-04-09 04:56:28
#
# Running experiment with num_cores=1, driver_memory=8g, parallelism=16
# Spark Version: 3.5.5, Parallelism: 16
# Driver memory: 8g
# +--------+------------+-----------+---------+
# |DISTANCE|CRS_DEP_TIME|WeatherCond|ARR_DELAY|
# +--------+------------+-----------+---------+
# |  1065.0|        1155|     Normal|    -14.0|
# |  1399.0|        2120|     Normal|     -5.0|
# |   680.0|         954|     Normal|      0.0|
# |  1589.0|        1609|     Normal|     24.0|
# |   985.0|        1840|     Normal|     -1.0|
# +--------+------------+-----------+---------+
# only showing top 5 rows
#
# Training set size: 2331968 records, Test set size: 581834 records
#
# --- Performance Metrics ---
# Training latency: 117.11 s for 2331968 records
# Training throughput: 19912.2 records/s
# Prediction latency: 45.05 s for 581834 records
# Prediction throughput: 12916.3 records/s
# RMSE: 50.19, R^2: 0.048
# Default parallelism (tasks): 16
# Train Data partitions: 16, Test Data partitions: 16
#
# Experiment Data Recorded:
#     num_cores driver_memory  parallelism  batch_interval file_size  \
# 35          1            8g           16             0.5        3m
#
#     train_duration_s  train_count  train_throughput_records_s  \
# 35        117.112734      2331968                19912.164318
#
#     pred_duration_s  test_count  pred_throughput_records_s       rmse  \
# 35        45.046602      581834               12916.268354  50.187366
#
#           r2  cpu_usage_start_percent  cpu_usage_end_percent  \
# 35  0.047984                     70.8                   70.9
#
#     mem_used_at_start_mb  mem_used_at_end_mb            timestamp
# 35           4559.878906         4557.390625  2025-04-09 05:00:47
#
# Running experiment with num_cores=2, driver_memory=8g, parallelism=2
# Spark Version: 3.5.5, Parallelism: 2
# Driver memory: 8g
# +--------+------------+-----------+---------+
# |DISTANCE|CRS_DEP_TIME|WeatherCond|ARR_DELAY|
# +--------+------------+-----------+---------+
# |  1065.0|        1155|     Normal|    -14.0|
# |  1399.0|        2120|     Normal|     -5.0|
# |   680.0|         954|     Normal|      0.0|
# |  1589.0|        1609|     Normal|     24.0|
# |   985.0|        1840|     Normal|     -1.0|
# +--------+------------+-----------+---------+
# only showing top 5 rows
#
# Training set size: 2330975 records, Test set size: 582827 records
#
# --- Performance Metrics ---
# Training latency: 112.60 s for 2330975 records
# Training throughput: 20700.7 records/s
# Prediction latency: 40.96 s for 582827 records
# Prediction throughput: 14230.5 records/s
# RMSE: 50.20, R^2: 0.047
# Default parallelism (tasks): 2
# Train Data partitions: 5, Test Data partitions: 5
#
# Experiment Data Recorded:
#     num_cores driver_memory  parallelism  batch_interval file_size  \
# 36          2            8g            2             0.5        3m
#
#     train_duration_s  train_count  train_throughput_records_s  \
# 36         112.60371      2330975                20700.694553
#
#     pred_duration_s  test_count  pred_throughput_records_s       rmse  \
# 36        40.956162      582827               14230.508311  50.200062
#
#          r2  cpu_usage_start_percent  cpu_usage_end_percent  \
# 36  0.04725                     88.5                   95.9
#
#     mem_used_at_start_mb  mem_used_at_end_mb            timestamp
# 36           4548.882812         4570.925781  2025-04-09 05:04:53
#
# Running experiment with num_cores=2, driver_memory=8g, parallelism=4
# Spark Version: 3.5.5, Parallelism: 4
# Driver memory: 8g
# +--------+------------+-----------+---------+
# |DISTANCE|CRS_DEP_TIME|WeatherCond|ARR_DELAY|
# +--------+------------+-----------+---------+
# |  1065.0|        1155|     Normal|    -14.0|
# |  1399.0|        2120|     Normal|     -5.0|
# |   680.0|         954|     Normal|      0.0|
# |  1589.0|        1609|     Normal|     24.0|
# |   985.0|        1840|     Normal|     -1.0|
# +--------+------------+-----------+---------+
# only showing top 5 rows
#
# Training set size: 2330975 records, Test set size: 582827 records
#
# --- Performance Metrics ---
# Training latency: 108.45 s for 2330975 records
# Training throughput: 21494.1 records/s
# Prediction latency: 42.22 s for 582827 records
# Prediction throughput: 13803.7 records/s
# RMSE: 50.20, R^2: 0.047
# Default parallelism (tasks): 4
# Train Data partitions: 5, Test Data partitions: 5
#
# Experiment Data Recorded:
#     num_cores driver_memory  parallelism  batch_interval file_size  \
# 37          2            8g            4             0.5        3m
#
#     train_duration_s  train_count  train_throughput_records_s  \
# 37          108.4472      2330975                21494.100437
#
#     pred_duration_s  test_count  pred_throughput_records_s       rmse  \
# 37        42.222402      582827                13803.73864  50.200062
#
#          r2  cpu_usage_start_percent  cpu_usage_end_percent  \
# 37  0.04725                     96.3                   95.6
#
#     mem_used_at_start_mb  mem_used_at_end_mb            timestamp
# 37           4569.914062           4576.4375  2025-04-09 05:08:53
#
# Running experiment with num_cores=2, driver_memory=8g, parallelism=8
# Spark Version: 3.5.5, Parallelism: 8
# Driver memory: 8g
# +--------+------------+-----------+---------+
# |DISTANCE|CRS_DEP_TIME|WeatherCond|ARR_DELAY|
# +--------+------------+-----------+---------+
# |  1065.0|        1155|     Normal|    -14.0|
# |  1399.0|        2120|     Normal|     -5.0|
# |   680.0|         954|     Normal|      0.0|
# |  1589.0|        1609|     Normal|     24.0|
# |   985.0|        1840|     Normal|     -1.0|
# +--------+------------+-----------+---------+
# only showing top 5 rows
#
# Training set size: 2332174 records, Test set size: 581628 records
#
# --- Performance Metrics ---
# Training latency: 109.94 s for 2332174 records
# Training throughput: 21214.1 records/s
# Prediction latency: 41.15 s for 581628 records
# Prediction throughput: 14132.7 records/s
# RMSE: 49.69, R^2: 0.046
# Default parallelism (tasks): 8
# Train Data partitions: 8, Test Data partitions: 8
#
# Experiment Data Recorded:
#     num_cores driver_memory  parallelism  batch_interval file_size  \
# 38          2            8g            8             0.5        3m
#
#     train_duration_s  train_count  train_throughput_records_s  \
# 38        109.935106      2332174                21214.097063
#
#     pred_duration_s  test_count  pred_throughput_records_s       rmse  \
# 38        41.154754      581628               14132.705166  49.685824
#
#           r2  cpu_usage_start_percent  cpu_usage_end_percent  \
# 38  0.045799                     97.8                   99.6
#
#     mem_used_at_start_mb  mem_used_at_end_mb            timestamp
# 38           4554.011719         4552.234375  2025-04-09 05:12:52
#
# Running experiment with num_cores=2, driver_memory=8g, parallelism=16
# Spark Version: 3.5.5, Parallelism: 16
# Driver memory: 8g
# +--------+------------+-----------+---------+
# |DISTANCE|CRS_DEP_TIME|WeatherCond|ARR_DELAY|
# +--------+------------+-----------+---------+
# |  1065.0|        1155|     Normal|    -14.0|
# |  1399.0|        2120|     Normal|     -5.0|
# |   680.0|         954|     Normal|      0.0|
# |  1589.0|        1609|     Normal|     24.0|
# |   985.0|        1840|     Normal|     -1.0|
# +--------+------------+-----------+---------+
# only showing top 5 rows
#
# Training set size: 2331968 records, Test set size: 581834 records
#
# --- Performance Metrics ---
# Training latency: 106.57 s for 2331968 records
# Training throughput: 21881.3 records/s
# Prediction latency: 41.28 s for 581834 records
# Prediction throughput: 14094.0 records/s
# RMSE: 50.19, R^2: 0.048
# Default parallelism (tasks): 16
# Train Data partitions: 16, Test Data partitions: 16
#
# Experiment Data Recorded:
#     num_cores driver_memory  parallelism  batch_interval file_size  \
# 39          2            8g           16             0.5        3m
#
#     train_duration_s  train_count  train_throughput_records_s  \
# 39        106.573348      2331968                21881.343157
#
#     pred_duration_s  test_count  pred_throughput_records_s       rmse  \
# 39        41.282427      581834               14093.987149  50.187366
#
#           r2  cpu_usage_start_percent  cpu_usage_end_percent  \
# 39  0.047984                     99.2                   99.7
#
#     mem_used_at_start_mb  mem_used_at_end_mb            timestamp
# 39           4769.726562          4772.15625  2025-04-09 05:16:47
#
# Running experiment with num_cores=4, driver_memory=8g, parallelism=2
# Spark Version: 3.5.5, Parallelism: 2
# Driver memory: 8g
# +--------+------------+-----------+---------+
# |DISTANCE|CRS_DEP_TIME|WeatherCond|ARR_DELAY|
# +--------+------------+-----------+---------+
# |  1065.0|        1155|     Normal|    -14.0|
# |  1399.0|        2120|     Normal|     -5.0|
# |   680.0|         954|     Normal|      0.0|
# |  1589.0|        1609|     Normal|     24.0|
# |   985.0|        1840|     Normal|     -1.0|
# +--------+------------+-----------+---------+
# only showing top 5 rows
#
# Training set size: 2330975 records, Test set size: 582827 records
#
# --- Performance Metrics ---
# Training latency: 112.12 s for 2330975 records
# Training throughput: 20790.2 records/s
# Prediction latency: 42.31 s for 582827 records
# Prediction throughput: 13776.4 records/s
# RMSE: 50.20, R^2: 0.047
# Default parallelism (tasks): 2
# Train Data partitions: 5, Test Data partitions: 5
#
# Experiment Data Recorded:
#     num_cores driver_memory  parallelism  batch_interval file_size  \
# 40          4            8g            2             0.5        3m
#
#     train_duration_s  train_count  train_throughput_records_s  \
# 40        112.119009      2330975                20790.185584
#
#     pred_duration_s  test_count  pred_throughput_records_s       rmse  \
# 40        42.306309      582827               13776.361273  50.200062
#
#          r2  cpu_usage_start_percent  cpu_usage_end_percent  \
# 40  0.04725                     96.8                   96.4
#
#     mem_used_at_start_mb  mem_used_at_end_mb            timestamp
# 40           4796.605469         4784.589844  2025-04-09 05:20:52
#
# Running experiment with num_cores=4, driver_memory=8g, parallelism=4
# Spark Version: 3.5.5, Parallelism: 4
# Driver memory: 8g
# +--------+------------+-----------+---------+
# |DISTANCE|CRS_DEP_TIME|WeatherCond|ARR_DELAY|
# +--------+------------+-----------+---------+
# |  1065.0|        1155|     Normal|    -14.0|
# |  1399.0|        2120|     Normal|     -5.0|
# |   680.0|         954|     Normal|      0.0|
# |  1589.0|        1609|     Normal|     24.0|
# |   985.0|        1840|     Normal|     -1.0|
# +--------+------------+-----------+---------+
# only showing top 5 rows
#
# Training set size: 2330975 records, Test set size: 582827 records
#
# --- Performance Metrics ---
# Training latency: 113.57 s for 2330975 records
# Training throughput: 20525.5 records/s
# Prediction latency: 42.98 s for 582827 records
# Prediction throughput: 13559.4 records/s
# RMSE: 50.20, R^2: 0.047
# Default parallelism (tasks): 4
# Train Data partitions: 5, Test Data partitions: 5
#
# Experiment Data Recorded:
#     num_cores driver_memory  parallelism  batch_interval file_size  \
# 41          4            8g            4             0.5        3m
#
#     train_duration_s  train_count  train_throughput_records_s  \
# 41        113.565036      2330975                20525.463564
#
#     pred_duration_s  test_count  pred_throughput_records_s       rmse  \
# 41        42.983376      582827               13559.358382  50.200062
#
#          r2  cpu_usage_start_percent  cpu_usage_end_percent  \
# 41  0.04725                     96.6                   95.9
#
#     mem_used_at_start_mb  mem_used_at_end_mb            timestamp
# 41           4775.546875         4775.800781  2025-04-09 05:25:02
#
# Running experiment with num_cores=4, driver_memory=8g, parallelism=8
# Spark Version: 3.5.5, Parallelism: 8
# Driver memory: 8g
# +--------+------------+-----------+---------+
# |DISTANCE|CRS_DEP_TIME|WeatherCond|ARR_DELAY|
# +--------+------------+-----------+---------+
# |  1065.0|        1155|     Normal|    -14.0|
# |  1399.0|        2120|     Normal|     -5.0|
# |   680.0|         954|     Normal|      0.0|
# |  1589.0|        1609|     Normal|     24.0|
# |   985.0|        1840|     Normal|     -1.0|
# +--------+------------+-----------+---------+
# only showing top 5 rows
#
# Training set size: 2332174 records, Test set size: 581628 records
#
# --- Performance Metrics ---
# Training latency: 107.88 s for 2332174 records
# Training throughput: 21619.1 records/s
# Prediction latency: 42.31 s for 581628 records
# Prediction throughput: 13747.2 records/s
# RMSE: 49.69, R^2: 0.046
# Default parallelism (tasks): 8
# Train Data partitions: 8, Test Data partitions: 8
#
# Experiment Data Recorded:
#     num_cores driver_memory  parallelism  batch_interval file_size  \
# 42          4            8g            8             0.5        3m
#
#     train_duration_s  train_count  train_throughput_records_s  \
# 42        107.875473      2332174                21619.131062
#
#     pred_duration_s  test_count  pred_throughput_records_s       rmse  \
# 42        42.308878      581628               13747.185578  49.685824
#
#           r2  cpu_usage_start_percent  cpu_usage_end_percent  \
# 42  0.045799                     98.3                   99.6
#
#     mem_used_at_start_mb  mem_used_at_end_mb            timestamp
# 42                4780.0         4777.199219  2025-04-09 05:29:01
#
# Running experiment with num_cores=4, driver_memory=8g, parallelism=16
# Spark Version: 3.5.5, Parallelism: 16
# Driver memory: 8g
# +--------+------------+-----------+---------+
# |DISTANCE|CRS_DEP_TIME|WeatherCond|ARR_DELAY|
# +--------+------------+-----------+---------+
# |  1065.0|        1155|     Normal|    -14.0|
# |  1399.0|        2120|     Normal|     -5.0|
# |   680.0|         954|     Normal|      0.0|
# |  1589.0|        1609|     Normal|     24.0|
# |   985.0|        1840|     Normal|     -1.0|
# +--------+------------+-----------+---------+
# only showing top 5 rows
#
# Training set size: 2331968 records, Test set size: 581834 records
#
# --- Performance Metrics ---
# Training latency: 106.94 s for 2331968 records
# Training throughput: 21805.8 records/s
# Prediction latency: 42.23 s for 581834 records
# Prediction throughput: 13778.3 records/s
# RMSE: 50.19, R^2: 0.048
# Default parallelism (tasks): 16
# Train Data partitions: 16, Test Data partitions: 16
#
# Experiment Data Recorded:
#     num_cores driver_memory  parallelism  batch_interval file_size  \
# 43          4            8g           16             0.5        3m
#
#     train_duration_s  train_count  train_throughput_records_s  \
# 43        106.942763      2331968                21805.757987
#
#     pred_duration_s  test_count  pred_throughput_records_s       rmse  \
# 43        42.228158      581834               13778.341853  50.187366
#
#           r2  cpu_usage_start_percent  cpu_usage_end_percent  \
# 43  0.047984                     99.2                   99.6
#
#     mem_used_at_start_mb  mem_used_at_end_mb            timestamp
# 43           4985.484375         4986.628906  2025-04-09 05:32:59
#
# Running experiment with num_cores=8, driver_memory=8g, parallelism=2
# Spark Version: 3.5.5, Parallelism: 2
# Driver memory: 8g
# +--------+------------+-----------+---------+
# |DISTANCE|CRS_DEP_TIME|WeatherCond|ARR_DELAY|
# +--------+------------+-----------+---------+
# |  1065.0|        1155|     Normal|    -14.0|
# |  1399.0|        2120|     Normal|     -5.0|
# |   680.0|         954|     Normal|      0.0|
# |  1589.0|        1609|     Normal|     24.0|
# |   985.0|        1840|     Normal|     -1.0|
# +--------+------------+-----------+---------+
# only showing top 5 rows
#
# Training set size: 2330975 records, Test set size: 582827 records
#
# --- Performance Metrics ---
# Training latency: 109.77 s for 2330975 records
# Training throughput: 21234.1 records/s
# Prediction latency: 41.86 s for 582827 records
# Prediction throughput: 13923.8 records/s
# RMSE: 50.20, R^2: 0.047
# Default parallelism (tasks): 2
# Train Data partitions: 5, Test Data partitions: 5
#
# Experiment Data Recorded:
#     num_cores driver_memory  parallelism  batch_interval file_size  \
# 44          8            8g            2             0.5        3m
#
#     train_duration_s  train_count  train_throughput_records_s  \
# 44        109.774941      2330975                21234.126655
#
#     pred_duration_s  test_count  pred_throughput_records_s       rmse  \
# 44        41.858283      582827               13923.815255  50.200062
#
#          r2  cpu_usage_start_percent  cpu_usage_end_percent  \
# 44  0.04725                     99.6                   99.8
#
#     mem_used_at_start_mb  mem_used_at_end_mb            timestamp
# 44           5005.359375         5024.207031  2025-04-09 05:37:00
#
# Running experiment with num_cores=8, driver_memory=8g, parallelism=4
# Spark Version: 3.5.5, Parallelism: 4
# Driver memory: 8g
# +--------+------------+-----------+---------+
# |DISTANCE|CRS_DEP_TIME|WeatherCond|ARR_DELAY|
# +--------+------------+-----------+---------+
# |  1065.0|        1155|     Normal|    -14.0|
# |  1399.0|        2120|     Normal|     -5.0|
# |   680.0|         954|     Normal|      0.0|
# |  1589.0|        1609|     Normal|     24.0|
# |   985.0|        1840|     Normal|     -1.0|
# +--------+------------+-----------+---------+
# only showing top 5 rows
#
# Training set size: 2330975 records, Test set size: 582827 records
#
# --- Performance Metrics ---
# Training latency: 108.75 s for 2330975 records
# Training throughput: 21434.1 records/s
# Prediction latency: 42.58 s for 582827 records
# Prediction throughput: 13686.8 records/s
# RMSE: 50.20, R^2: 0.047
# Default parallelism (tasks): 4
# Train Data partitions: 5, Test Data partitions: 5
#
# Experiment Data Recorded:
#     num_cores driver_memory  parallelism  batch_interval file_size  \
# 45          8            8g            4             0.5        3m
#
#     train_duration_s  train_count  train_throughput_records_s  \
# 45        108.750825      2330975                21434.090331
#
#     pred_duration_s  test_count  pred_throughput_records_s       rmse  \
# 45        42.583152      582827               13686.798067  50.200062
#
#          r2  cpu_usage_start_percent  cpu_usage_end_percent  \
# 45  0.04725                     99.4                   99.8
#
#     mem_used_at_start_mb  mem_used_at_end_mb            timestamp
# 45           5033.007812          5033.03125  2025-04-09 05:41:00
#
# Running experiment with num_cores=8, driver_memory=8g, parallelism=8
# Spark Version: 3.5.5, Parallelism: 8
# Driver memory: 8g
# +--------+------------+-----------+---------+
# |DISTANCE|CRS_DEP_TIME|WeatherCond|ARR_DELAY|
# +--------+------------+-----------+---------+
# |  1065.0|        1155|     Normal|    -14.0|
# |  1399.0|        2120|     Normal|     -5.0|
# |   680.0|         954|     Normal|      0.0|
# |  1589.0|        1609|     Normal|     24.0|
# |   985.0|        1840|     Normal|     -1.0|
# +--------+------------+-----------+---------+
# only showing top 5 rows
#
# Training set size: 2332174 records, Test set size: 581628 records
#
# --- Performance Metrics ---
# Training latency: 113.14 s for 2332174 records
# Training throughput: 20612.5 records/s
# Prediction latency: 44.19 s for 581628 records
# Prediction throughput: 13162.1 records/s
# RMSE: 49.69, R^2: 0.046
# Default parallelism (tasks): 8
# Train Data partitions: 8, Test Data partitions: 8
#
# Experiment Data Recorded:
#     num_cores driver_memory  parallelism  batch_interval file_size  \
# 46          8            8g            8             0.5        3m
#
#     train_duration_s  train_count  train_throughput_records_s  \
# 46        113.143658      2332174                20612.503059
#
#     pred_duration_s  test_count  pred_throughput_records_s       rmse  \
# 46        44.189656      581628               13162.084875  49.685824
#
#           r2  cpu_usage_start_percent  cpu_usage_end_percent  \
# 46  0.045799                     99.4                   99.7
#
#     mem_used_at_start_mb  mem_used_at_end_mb            timestamp
# 46           5005.917969         5028.960938  2025-04-09 05:45:07
#
# Running experiment with num_cores=8, driver_memory=8g, parallelism=16
# Spark Version: 3.5.5, Parallelism: 16
# Driver memory: 8g
# +--------+------------+-----------+---------+
# |DISTANCE|CRS_DEP_TIME|WeatherCond|ARR_DELAY|
# +--------+------------+-----------+---------+
# |  1065.0|        1155|     Normal|    -14.0|
# |  1399.0|        2120|     Normal|     -5.0|
# |   680.0|         954|     Normal|      0.0|
# |  1589.0|        1609|     Normal|     24.0|
# |   985.0|        1840|     Normal|     -1.0|
# +--------+------------+-----------+---------+
# only showing top 5 rows
#
# Training set size: 2331968 records, Test set size: 581834 records
#
# --- Performance Metrics ---
# Training latency: 112.36 s for 2331968 records
# Training throughput: 20755.1 records/s
# Prediction latency: 41.38 s for 581834 records
# Prediction throughput: 14061.2 records/s
# RMSE: 50.19, R^2: 0.048
# Default parallelism (tasks): 16
# Train Data partitions: 16, Test Data partitions: 16
#
# Experiment Data Recorded:
#     num_cores driver_memory  parallelism  batch_interval file_size  \
# 47          8            8g           16             0.5        3m
#
#     train_duration_s  train_count  train_throughput_records_s  \
# 47        112.356587      2331968                20755.062642
#
#     pred_duration_s  test_count  pred_throughput_records_s       rmse  \
# 47        41.378669      581834               14061.206181  50.187366
#
#           r2  cpu_usage_start_percent  cpu_usage_end_percent  \
# 47  0.047984                     99.5                   99.7
#
#     mem_used_at_start_mb  mem_used_at_end_mb            timestamp
# 47           4999.101562         5643.265625  2025-04-09 05:49:12

# %%
results_df.to_excel(excel_filename, index=False)
print(f"\nResults saved to {excel_filename}")
# Out:
# Results saved to /content/drive/MyDrive/SENG_533/spark_phase2_results.xlsx

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the Excel data into a DataFrame
df = pd.read_excel(excel_filename)

# Create a copy for analysis and preprocess data
df_analysis = df.copy()

# Convert driver_memory from strings like "8g" to numeric (in GB)
df_analysis['driver_memory_gb'] = df_analysis['driver_memory'].str.replace('g', '', case=False).astype(int)

# Define performance metrics:
# Throughput: training throughput in records per second
df_analysis['throughput'] = df_analysis['train_throughput_records_s']

# Latency: average prediction latency per record (ms)
df_analysis['latency_ms'] = (df_analysis['pred_duration_s'] / df_analysis['test_count']) * 1000

# Resource Utilization: peak CPU usage (max of start and end)
df_analysis['cpu_util_percent'] = df_analysis[['cpu_usage_start_percent', 'cpu_usage_end_percent']].max(axis=1)

# Convert 'file_size' to a numerical representation
file_size_mapping = {'1k': 1000, '500k': 500000, '3m': 3000000, 'unknown': -1}
df_analysis['file_size_numeric'] = df_analysis['file_size'].map(file_size_mapping)

# Ensure we have all file sizes before applying qcut
unique_file_sizes = df_analysis['file_size'].unique()
if len(unique_file_sizes) >= 3:
    df_analysis['file_size_bin'] = pd.qcut(df_analysis['file_size_numeric'],
                                          q=min(3, len(unique_file_sizes)),
                                          labels=['small', 'medium', 'large'],
                                          duplicates='drop')
else:
    # If we have fewer than 3 unique sizes, just use the original file_size as the bin
    df_analysis['file_size_bin'] = df_analysis['file_size']

# Define factors and performance metrics
factors = ['num_cores', 'parallelism']  # Removed driver_memory as it's fixed in Phase 2
metrics = ['throughput', 'latency_ms', 'cpu_util_percent']

# Create line graphs for each factor vs each performance metric, grouped by file size bins
for factor in factors:
    fig, axes = plt.subplots(1, len(metrics), figsize=(16, 4), sharey=False)
    for ax, metric in zip(axes, metrics):
        # Group the data by the factor and file_size_bin and calculate the mean metric value
        grouped = df_analysis.groupby([factor, 'file_size_bin'])[metric].mean().reset_index()

        # For each file size bin, sort the data by factor and plot a line
        for file_size_bin in grouped['file_size_bin'].unique():
            subset = grouped[grouped['file_size_bin'] == file_size_bin]
            # Sort by the factor to ensure a connected line plot
            subset = subset.sort_values(by=factor)
            ax.plot(subset[factor], subset[metric], marker='o', label=f'File Size: {file_size_bin}')

        ax.set_xlabel(factor)
        ax.set_ylabel(metric)
        ax.set_title(f"{metric} vs {factor}")
        ax.legend()

    fig.suptitle(f"Impact of {factor} on Performance Metrics\n(Line graphs grouped by File Size)", fontsize=14)
    plt.tight_layout()
    plt.show()
# Out:
# <ipython-input-12-f8fada6ba4d0>:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = df_analysis.groupby([factor, 'file_size_bin'])[metric].mean().reset_index()
# <ipython-input-12-f8fada6ba4d0>:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = df_analysis.groupby([factor, 'file_size_bin'])[metric].mean().reset_index()
# <ipython-input-12-f8fada6ba4d0>:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = df_analysis.groupby([factor, 'file_size_bin'])[metric].mean().reset_index()
# <ipython-input-12-f8fada6ba4d0>:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = df_analysis.groupby([factor, 'file_size_bin'])[metric].mean().reset_index()
# <ipython-input-12-f8fada6ba4d0>:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = df_analysis.groupby([factor, 'file_size_bin'])[metric].mean().reset_index()
# <ipython-input-12-f8fada6ba4d0>:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = df_analysis.groupby([factor, 'file_size_bin'])[metric].mean().reset_index()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the Excel data into a DataFrame
df = pd.read_excel(excel_filename)

# Create a copy for analysis and preprocess data
df_analysis = df.copy()

# Define performance metrics
df_analysis['throughput'] = df_analysis['train_throughput_records_s']
df_analysis['latency_ms'] = (df_analysis['pred_duration_s'] / df_analysis['test_count']) * 1000
df_analysis['cpu_util_percent'] = df_analysis[['cpu_usage_start_percent', 'cpu_usage_end_percent']].max(axis=1)

# Convert 'file_size' to a numerical representation
file_size_mapping = {'1k': 1000, '500k': 500000, '3m': 3000000, 'unknown': -1}
df_analysis['file_size_numeric'] = df_analysis['file_size'].map(file_size_mapping)

# Ensure we have all file sizes before applying qcut
unique_file_sizes = df_analysis['file_size'].unique()
if len(unique_file_sizes) >= 3:
    df_analysis['file_size_bin'] = pd.qcut(df_analysis['file_size_numeric'],
                                          q=min(3, len(unique_file_sizes)),
                                          labels=['small', 'medium', 'large'],
                                          duplicates='drop')
else:
    # If we have fewer than 3 unique sizes, just use the original file_size as the bin
    df_analysis['file_size_bin'] = df_analysis['file_size']

# Define factors and performance metrics (fixed to use correct column names)
factors = ['num_cores', 'parallelism']  # Removed driver_memory as it's fixed in Phase 2
metrics = ['throughput', 'latency_ms', 'cpu_util_percent']

# Create bar charts for summarizing file size impacts
plt.figure(figsize=(12, 6))
for i, metric in enumerate(['throughput', 'latency_ms', 'cpu_util_percent']):
    plt.subplot(1, 3, i+1)
    df_analysis.groupby('file_size')[metric].mean().plot(kind='bar', color='skyblue')
    plt.title(f'Avg {metric} by File Size')
    plt.ylabel(metric)
    plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# Create heatmap to show relationship between num_cores and parallelism
plt.figure(figsize=(10, 8))
pivot_throughput = df_analysis.pivot_table(
    values='throughput',
    index='num_cores',
    columns='parallelism',
    aggfunc='mean'
)
plt.imshow(pivot_throughput, cmap='viridis', interpolation='nearest', aspect='auto')
plt.colorbar(label='Throughput (records/s)')
plt.title('Performance Heatmap: Cores vs Parallelism')
plt.xlabel('Parallelism')
plt.ylabel('Number of Cores')
plt.xticks(range(len(pivot_throughput.columns)), pivot_throughput.columns)
plt.yticks(range(len(pivot_throughput.index)), pivot_throughput.index)

for i in range(len(pivot_throughput.index)):
    for j in range(len(pivot_throughput.columns)):
        plt.text(j, i, f'{pivot_throughput.iloc[i, j]:.0f}',
                 ha='center', va='center', color='white')

plt.tight_layout()
plt.show()
